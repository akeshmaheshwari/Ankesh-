# %% [markdown]
# <a href="https://colab.research.google.com/github/akeshmaheshwari/Ankesh-/blob/main/Copy_of_Ankesh_Python_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var=10

# %%
var
# Out:
# 20

# %%
var=20

# %%
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3585/4138207136.py in <cell line: 0>()
# ----> 1 var
#
# NameError: name 'var' is not defined

# %%
var_1=10

# %%
_var=10

# %%
_Var=20

# %%
_Var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3585/787036961.py in <cell line: 0>()
# ----> 1 _Var
#
# NameError: name '_Var' is not defined

# %%
X=10

# %%
type(X)
# Out:
# int

# %%
X=10.25

# %%
type(X)
# Out:
# str

# %%
X=True

# %%
type(X)
# Out:
# bool

# %%
X=False

# %%
type(X)
# Out:
# complex

# %%
X=3+2j

# %%
type(X)
# Out:
# complex

# %%
X=[1,2,3,'Hello']

# %%
X
# Out:
# [1, 2, 3, 'Hello']

# %%
type(X)
# Out:
# list

# %%
X=(1,2,3,'Hello')

# %%
type(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_888/1535897611.py in <cell line: 0>()
# ----> 1 type(X)
#
# NameError: name 'X' is not defined

# %%
X
# Out:
# (1, 2, 3, 'Hello')

# %%
type(X)
# Out:
# tuple

# %%
X={1,2,3,'Hello'}

# %%
type(X)
# Out:
# set

# %%
X = {'Black':11,'Red':12,'Green':13}

# %%
X
# Out:
# {'Black': 11, 'Red': 12, 'Green': 13}

# %%
type(X)
# Out:
# dict

# %%
Type casting
# Out:
#   File "/tmp/ipykernel_3585/2166152381.py", line 1
#     Type casting
#          ^
# SyntaxError: invalid syntax

# %%
#int -> float-> string

# %%
X ='12'

# %%
type(X)
# Out:
# str

# %%
y =int(X)

# %%
type(y)
# Out:
# int

# %%
int('12')
# Out:
# 12

# %%
int(12)
# Out:
# 12

# %%
int(12.25)
# Out:
# 12

# %%
str(12.45)
# Out:
# '12.45'

# %%
float ('12.25')
# Out:
# 12.25

# %%
int(float(12.25))
# Out:
# 12

# %%
input()
# Out:
# 10
# '10'

# %%
input("Enter your age")
# Out:
# Enter your age24
# '24'

# %%
X =input("Enter your Age:")
# Out:
# Enter your Age:10

# %%
X
# Out:
# '10'

# %%
X=float(input("Enter your Age:"))
# Out:
# Enter your Age:10

# %%
X
# Out:
# 10.0

# %%
type(X)
# Out:
# float

# %%
X
# Out:
# 10.0

# %%
X=25

# %%
print(X)
# Out:
# 25

# %%
print('y')
# Out:
# y

# %%
print('my age is, X')
# Out:
# my age is, X

# %%
y=x+30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3585/3668281776.py in <cell line: 0>()
# ----> 1 y=x+30
#
# NameError: name 'x' is not defined

# %%
X=int(input("Sam enter your age:"))
# Out:
# Sam enter your age:25

# %%
X
# Out:
# 25

# %%
y=X+30

# %%
y
# Out:
# 55

# %%
print("Sam is, X, years old and his father is", y, "years old. ")
# Out:
# Sam is, X, years old and his father is 55 years old.

# %%
print("Sam is {a} years old and his father is {b} years old.".format(a=X,b=y))
# Out:
# Sam is 25 years old and his father is 55 years old.

# %%
print("Sam is {0} years. old and his father is {1} years old.".format(X,y))
# Out:
# Sam is 25 years. old and his father is 55 years old.

# %%
print("Sam is {} years old and his father is {} years old.".format(10,20))
# Out:
# Sam is 10 years old and his father is 20 years old.

# %%
print("Sam is {} years old and his father is {} years old".format(X,y))
# Out:
# Sam is 25 years old and his father is 55 years old
